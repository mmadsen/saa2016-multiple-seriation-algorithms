# %% [markdown]
# # Table of Contents
#  <p>

# %% [raw]
# <script>
#   jQuery(document).ready(function($) {
#
#   $(window).load(function(){
#     $('#preloader').fadeOut('slow',function(){$(this).remove();});
#   });
#
#   });
# </script>
#
# <style type="text/css">
#   div#preloader { position: fixed;
#       left: 0;
#       top: 0;
#       z-index: 999;
#       width: 100%;
#       height: 100%;
#       overflow: visible;
#       background: #fff url('http://preloaders.net/preloaders/720/Moving%20line.gif') no-repeat center center;
#   }
#
# </style>
#
# <div id="preloader">
#
# </div>

# %% [raw]
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>

# %% [markdown]
# # SAA 2016 Analysis #

# %%
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# From command line, isomorphism check:
#
# mark:train-early-split/ (master*) $ python ~/src/seriationct/analytics/seriationct-compare-seriation-pairs.py --frequencydir ./frequency --continuitydir ./continuity
#
# identical: 39  different:  11  unmatched: 0
#
# list of different sim_ids:
#
# a7f306c4-d451-11e5-ab76-086266a2412a-0
#
# 219b95fc-d454-11e5-933c-086266a2412a-0
#
# 21271b5a-d459-11e5-ac28-086266a2412a-0
#
# c8729572-d460-11e5-a891-086266a2412a-0
#
# 769a8a24-d457-11e5-aa98-086266a2412a-0
#
# 4012d938-d44e-11e5-8528-086266a2412a-0
#
# a10cbde6-d45b-11e5-8a80-086266a2412a-0
#
# 495be6ba-d458-11e5-8091-086266a2412a-0
#
# 5dbbe5dc-d463-11e5-8660-086266a2412a-0
#
# 10d98616-d44f-11e5-9ed3-086266a2412a-0
#
# f8a6f378-d465-11e5-a9f4-086266a2412a-0

# %%
freq_g = nx.read_gml("train-early-split/frequency/f8a6f378-d465-11e5-a9f4-086266a2412a-0-sampled-500-slicestratified-0.05-resample-0-0.1-unimodal-filtered-minmax-by-weight-frequency.gml")
cont_g = nx.read_gml("train-early-split/continuity/f8a6f378-d465-11e5-a9f4-086266a2412a-0-sampled-500-slicestratified-0.05-resample-0-0.1-unimodal-filtered-minmax-by-weight-continuity.gml")

# %%
label_map = dict()
for n,d in freq_g.nodes_iter(data=True):
    label_map[n] = freq_g.node[n]['label']

# %%
plt.figure(figsize=(12,8))
pos = nx.graphviz_layout(freq_g, prog="neato")
nx.draw_networkx(freq_g, pos, with_labels=True, labels = label_map)
plt.savefig("f8a6f378-freq.png")

# %%
plt.figure(figsize=(12,8))
label_map = dict()
for n,d in cont_g.nodes_iter(data=True):
    label_map[n] = cont_g.node[n]['label']
pos = nx.graphviz_layout(cont_g, prog="neato")
nx.draw_networkx(cont_g, pos, with_labels=True, labels = label_map)
plt.savefig("f8a6f378-cont.png")

# %%
freq_g = nx.read_gml("train-early-split/frequency/21271b5a-d459-11e5-ac28-086266a2412a-0-sampled-500-slicestratified-0.05-resample-0-0.1-unimodal-filtered-minmax-by-weight-frequency.gml")
cont_g = nx.read_gml("train-early-split/continuity/21271b5a-d459-11e5-ac28-086266a2412a-0-sampled-500-slicestratified-0.05-resample-0-0.1-unimodal-filtered-minmax-by-weight-continuity.gml")

# %%
plt.figure(figsize=(12,8))
pos = nx.graphviz_layout(freq_g, prog="neato")
nx.draw_networkx(freq_g, pos, with_labels=True, labels = label_map)
plt.savefig("21271b5a-freq.png")

plt.figure(figsize=(12,8))
label_map = dict()
for n,d in cont_g.nodes_iter(data=True):
    label_map[n] = cont_g.node[n]['label']
pos = nx.graphviz_layout(cont_g, prog="neato")
nx.draw_networkx(cont_g, pos, with_labels=True, labels = label_map)
plt.savefig("21271b5a-cont.png")

# %%
import pandas as pd

# %%
f8a6f378_cont = pd.read_csv("f8a6f378-solutions-continuity.csv")
f8a6f378_freq = pd.read_csv("f8a6f378-solutions-frequency.csv")

# %% [raw]
# <script>
#   $(document).ready(function(){
#     $('div.prompt').hide();
#     $('div.back-to-top').hide();
#     $('nav#menubar').hide();
#     $('.breadcrumb').hide();
#     $('.hidden-print').hide();
#   });
# </script>
